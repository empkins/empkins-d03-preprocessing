# %%
import json
import re
from pathlib import Path

import pandas as pd
import numpy as np
import pingouin as pg

import matplotlib.pyplot as plt
import seaborn as sns

from fau_colors import cmaps, register_fausans_font
import biopsykit as bp

from empkins_io.datasets.d03.micro_gapvii import MicroBaseDataset

import shutil

# %load_ext autoreload
# %autoreload 2
# %matplotlib widget
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
register_fausans_font()
plt.close("all")

palette = sns.color_palette(cmaps.faculties)
sns.set_theme(context="notebook", style="ticks", palette=palette)

plt.rcParams["figure.figsize"] = (8, 4)
plt.rcParams["pdf.fonttype"] = 42
plt.rcParams["mathtext.default"] = "regular"
plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.sans-serif"] = "FAUSans Office"

palette
# Out:
# [(0.0, 0.1843137254901961, 0.4235294117647059),
#  (0.4666666666666667, 0.6235294117647059, 0.7098039215686275),
#  (1.0, 0.7215686274509804, 0.10980392156862745),
#  (0.0, 0.6392156862745098, 0.8784313725490196),
#  (0.2627450980392157, 0.6901960784313725, 0.16470588235294117),
#  (0.7843137254901961, 0.06274509803921569, 0.1803921568627451)]

# %%
deploy_type = "local"

config_dict = json.load(Path("../config.json").open(encoding="utf-8"))

base_path = Path(config_dict[deploy_type]["base_path"])
base_path
# Out:
# PosixPath('/Volumes/luca_ssd/Study_Data/2022_12_GAPVII_Micro')

# %%
dataset = MicroBaseDataset(base_path=base_path)

# %%
folder_path = Path("/Users/abelluc/Data/NilsPod_Sorted_DONE")

# %%
subject = "VP_050"
condition = "tsst"

# build path
path_in = folder_path.joinpath(f"{subject}/{condition}")
path_out = dataset.base_path.joinpath("data_per_subject", subject, condition, "nilspod/raw")
print(path_out)

# copy all files from path_in to path_out
shutil.copytree(path_in, path_out, dirs_exist_ok=True)
# Out:
# /Volumes/luca_ssd/Study_Data/2022_12_GAPVII_Micro/data_per_subject/VP_050/tsst/nilspod/raw
# PosixPath('/Volumes/luca_ssd/Study_Data/2022_12_GAPVII_Micro/data_per_subject/VP_050/tsst/nilspod/raw')
